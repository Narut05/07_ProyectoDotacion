# %% [markdown]
# ### 00 LIBRERIAS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from glob import glob
# Aplicar configuraciones de visualización total de Pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

from pathlib import Path
import glob

import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

# %% [markdown]
# ### 01 EXTRACT

# %%
df = pd.read_excel(r"input\Productividad 2026 v4 --- ep.xlsx", sheet_name="AgrupacionTda", header=3)

# %%
df.head()
# Out:
#    Grupo GOS/GOR    Grupo EO                      Obs  \
# 0            NaN  Li_Hiper A  HIPER_Lima + Callao_A_A
# 1            NaN  Li_Hiper A  HIPER_Lima + Callao_A_A
# 2            NaN  Li_Hiper A  HIPER_Lima + Callao_A_A
# 3            NaN  Li_Hiper A  HIPER_Lima + Callao_A_A
# 4            NaN  Li_Hiper A  HIPER_Lima + Callao_A_A
#
#                         Tienda EsMultif          formato formato2  \
# 0  P010_Caminos del Inca - PVS   Normal  PLAZA VEA SUPER    HIPER
# 1        P064_Miraflores - PVH   Normal        PLAZA VEA    HIPER
# 2         P081_La Molina - PVH   Normal        PLAZA VEA    HIPER
# 3         P195_San Borja - PVH   Normal        PLAZA VEA    HIPER
# 4     P106_Valle Hermoso - PVH   Normal        PLAZA VEA    HIPER
#
#        ubicacion cluster Cluster Comercial Cluster NSE Cluster NSE Comercial  \
# 0  Lima + Callao      A2                A2           A                     A
# 1  Lima + Callao      A3                A3           A                     A
# ...

# %% [markdown]
# ### 02 TRANSFORM

# %%
df["cluster_tienda"] = df["Grupo EO"]
df1 = df[["Tienda", "cluster_tienda"]]

# %%
df1.groupby("cluster_tienda")["Tienda"].nunique()
# Out:
# cluster_tienda
# Dasso                1
# Li_Hiper A           7
# Li_Hiper BC2        12
# Li_Hiper BC3         9
# Li_Hiper BC4        10
# Li_Hiper BC5         4
# Multifuncionales    19
# PV Super             7
# Prov_Hiper BC1       6
# Prov_Hiper BC3      15
# Prov_Hiper BC4       9
# Temporada           10
# Vivandas             5
# Name: Tienda, dtype: int64

# %% [markdown]
# ### 03 LOAD

# %%
df1.to_parquet(r"output\ClusterTiendas.parquet")
