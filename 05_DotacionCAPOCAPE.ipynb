# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from glob import glob
# Aplicar configuraciones de visualización total de Pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

from pathlib import Path
import glob

import warnings
warnings.filterwarnings("ignore")
import plotly.express as px

import func_negocio as func

# %%
bd_ventas = r"output\VentasReal.parquet"

# %%
df_ventas = pd.read_parquet(bd_ventas)

# %%
df_ventas["Anio"]= df_ventas["Anio"].astype(int).astype(str)
df_ventas["NroMes"]= df_ventas["NroMes"].astype(int)

# %%
df_ventas1 = df_ventas.pivot_table(index=["_Tienda", "_Tipo", "NroMes"], columns="Anio", values="Vta.", aggfunc="sum", fill_value=0).reset_index()

# %%
df_ventas2 = df_ventas1[df_ventas1["NroMes"]<=5]
df_ventas2
# Out:
# Anio                    _Tienda      _Tipo  NroMes        2025        2026
# 0      1198_Cusco Wanchaq - PVH  ABARROTES       1  1607446.78  1859223.11
# 1      1198_Cusco Wanchaq - PVH  ABARROTES       2  1529432.86  1692691.20
# 2      1198_Cusco Wanchaq - PVH  ABARROTES       3  1821395.85  2181793.08
# 3      1198_Cusco Wanchaq - PVH  ABARROTES       4  1731520.05  2067549.23
# 4      1198_Cusco Wanchaq - PVH  ABARROTES       5  1865308.42  2218111.20
# ...                         ...        ...     ...         ...         ...
# 12143     X210_Santa Cruz - PVE  RECEPCION       1   334725.40   321625.64
# 12144     X210_Santa Cruz - PVE  RECEPCION       2   317772.87   312656.28
# 12145     X210_Santa Cruz - PVE  RECEPCION       3   357972.50   375877.05
# 12146     X210_Santa Cruz - PVE  RECEPCION       4   346279.09   343397.14
# 12147     X210_Santa Cruz - PVE  RECEPCION       5   342287.54   359752.80
#
# [5085 rows x 5 columns]
